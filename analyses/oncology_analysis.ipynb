# %% [markdown]
# # Oncology Population Analysis
#
# **Schemas:**
# - `dim_patient` - Patient dimension with cohort attributes and cancer codes
# - `dim_cancer_type` - Cancer type reference with ICD-10 ranges
# - `dim_care_setting` - Care setting reference with detail (e.g., inpatient/acute inpatient, outpatient/emergency department)
# - `dim_spend_bucket` - Spend tier segmentation
# - `fact_oncology_cost` - Fact table with foreign keys to dimensions

# %%
import duckdb

con = duckdb.connect('../local.duckdb', read_only=True)

con.sql("""
    SELECT name 
    FROM sqlite_master 
    WHERE type='table' 
    AND (name LIKE 'dim_%' OR name LIKE 'fact_oncology%')
    ORDER BY name
""").show()
# Out:
# ┌──────────────────────────────┐
# │             name             │
# │           varchar            │
# ├──────────────────────────────┤
# │ dim_cancer_type              │
# │ dim_care_setting             │
# │ dim_patient                  │
# │ dim_spend_bucket             │
# │ fact_oncology_cost           │
# │ fact_oncology_cost_analytics │
# │ fact_oncology_patient_detail │
# └──────────────────────────────┘

# %% [markdown]
# ## Dimension Tables Overview

# %% [markdown]
# #### Dim Cancer Type

# %%
con.sql("""
    SELECT 
        cancer_type_key,
        cancer_type_name,
        category,
        icd10_range_start,
        icd10_range_end
    FROM main.dim_cancer_type
    ORDER BY sort_order
""").df()
# Out:
#     cancer_type_key               cancer_type_name     category  \
# 0                 1     Lip, Oral Cavity & Pharynx    Malignant
# 1                 2               Digestive Organs    Malignant
# 2                 3    Respiratory & Intrathoracic    Malignant
# 3                 4     Bone & Articular Cartilage    Malignant
# 4                 5                Melanoma & Skin    Malignant
# 5                 6      Mesothelial & Soft Tissue    Malignant
# 6                 7                         Breast    Malignant
# 7                 8          Female Genital Organs    Malignant
# 8                 9            Male Genital Organs    Malignant
# 9                10                  Urinary Tract    Malignant
# 10               11               Eye, Brain & CNS    Malignant
# 11               12     Thyroid & Endocrine Glands    Malignant
# 12               13  Ill-defined & Secondary Sites    Malignant
# 13               14          Neuroendocrine Tumors    Malignant
# 14               15       Secondary Neuroendocrine    Malignant
# 15               16                    Hematologic    Malignant
# 16               17              In Situ Neoplasms      In Situ
# 17               18               Benign Neoplasms       Benign
# 18               19             Uncertain Behavior    Uncertain
# 19               20          Benign Neuroendocrine       Benign
# 20               21           Unspecified Behavior  Unspecified
# 21               99                 Other Neoplasm        Other
#
#    icd10_range_start icd10_range_end
# 0                C00             C15
# 1                C15             C27
# 2                C30             C40
# 3                C40             C42
# 4                C43             C45
# 5                C45             C50
# 6                C50             C51
# 7                C51             C59
# 8                C60             C64
# 9                C64             C69
# 10               C69             C73
# 11               C73             C76
# 12               C76             C7A
# 13               C7A             C7B
# 14               C7B             C81
# 15               C81             C97
# 16               D00             D10
# 17               D10             D37
# 18               D37             D49
# 19               D3A             D3B
# 20               D49             D50
# 21              None            None

# %% [markdown]
# #### Dim Care Setting

# %%
con.sql("""
    SELECT 
        care_setting_key,
        care_setting_code,
        care_setting_name,
        care_setting_detail_code,
        care_setting_detail_name,
        sort_order
    FROM main.dim_care_setting
    ORDER BY sort_order, care_setting_detail_name
""").df()
# Out:
#     care_setting_key care_setting_code care_setting_name  \
# 0                  1         inpatient         Inpatient
# 1                  2         inpatient         Inpatient
# 2                  3         inpatient         Inpatient
# 3                  4         inpatient         Inpatient
# 4                  5         inpatient         Inpatient
# 5                  6        outpatient        Outpatient
# 6                  7        outpatient        Outpatient
# 7                  8        outpatient        Outpatient
# 8                  9        outpatient        Outpatient
# 9                 10        outpatient        Outpatient
# 10                11        outpatient        Outpatient
# 11                12        outpatient        Outpatient
# 12                13        outpatient        Outpatient
# 13                14        outpatient        Outpatient
# 14                15        outpatient        Outpatient
# 15                16        outpatient        Outpatient
# 16                17        outpatient        Outpatient
# 17                18        outpatient        Outpatient
# 18                19        outpatient        Outpatient
# 19                20      office-based      Office Based
# 20                21      office-based      Office Based
# 21                22      office-based      Office Based
# 22                23      office-based      Office Based
# 23                24      office-based      Office Based
# 24                25      office-based      Office Based
# 25                26         ancillary         Ancillary
# 26                27         ancillary         Ancillary
# 27                28         ancillary         Ancillary
# 28                29             other           Unknown
#
#          care_setting_detail_code       care_setting_detail_name  sort_order
# 0                 acute inpatient                acute inpatient           1
# 1           inpatient psychiatric          inpatient psychiatric           1
# 2        inpatient rehabilitation       inpatient rehabilitation           1
# 3                        pharmacy                       pharmacy           1
# 4                 skilled nursing                skilled nursing           1
# 5       ambulatory surgery center      ambulatory surgery center           2
# 6                        dialysis                       dialysis           2
# 7            emergency department           emergency department           2
# 8                     home health                    home health           2
# 9                     observation                    observation           2
# 10             outpatient hospice             outpatient hospice           2
# 11  outpatient hospital or clinic  outpatient hospital or clinic           2
# 12         outpatient psychiatric         outpatient psychiatric           2
# 13            outpatient pt/ot/st            outpatient pt/ot/st           2
# 14           outpatient radiology           outpatient radiology           2
# 15      outpatient rehabilitation      outpatient rehabilitation           2
# 16             outpatient surgery             outpatient surgery           2
# 17                       pharmacy                       pharmacy           2
# 18                    urgent care                    urgent care           2
# 19             office-based other             office based other           3
# 20          office-based pt/ot/st          office based pt/ot/st           3
# 21         office-based radiology         office based radiology           3
# 22             office-based visit             office based visit           3
# 23                       pharmacy                       pharmacy           3
# 24               telehealth visit               telehealth visit           3
# 25                      ambulance                      ambulance           4
# 26      durable medical equipment      durable medical equipment           4
# 27                            lab                            lab           4
# 28                          other                          other          99

# %% [markdown]
# #### Dim Spend Bucket

# %%
con.sql("""
    SELECT *
    FROM main.dim_spend_bucket
    ORDER BY sort_order
""").df()
# Out:
#    spend_bucket_key         spend_bucket_name  min_threshold  max_threshold  \
# 0                 1        High Cost (>$100k)       100000.0            NaN
# 1                 2  Medium Cost ($25k-$100k)        25000.0       99999.99
# 2                 3       Low Cost ($5k-$25k)         5000.0       24999.99
# 3                 4       Minimal Cost (<$5k)            0.0        4999.99
#
#    sort_order
# 0           1
# 1           2
# 2           3
# 3           4

# %% [markdown]
# #### Dim Patient

# %%
cohort_df = con.sql("""
    SELECT 
        p.primary_cancer_type,
        ct.category,
        COUNT(*) as patient_count,
        AVG(p.cancer_claim_count) as avg_claims_per_patient
    FROM main.dim_patient p
    LEFT JOIN main.dim_cancer_type ct
        ON p.primary_cancer_type = ct.cancer_type_name
    GROUP BY 1, 2
    ORDER BY patient_count DESC
""").df()

cohort_df
# Out:
#               primary_cancer_type     category  patient_count  \
# 0                Benign Neoplasms       Benign            241
# 1              Uncertain Behavior    Uncertain             65
# 2                 Melanoma & Skin    Malignant             45
# 3             Male Genital Organs    Malignant             33
# 4                  Other Neoplasm        Other             20
# 5                          Breast    Malignant             13
# 6                     Hematologic    Malignant             12
# 7                   Urinary Tract    Malignant             11
# 8      Thyroid & Endocrine Glands    Malignant              6
# 9                Digestive Organs    Malignant              6
# 10              In Situ Neoplasms      In Situ              5
# 11           Unspecified Behavior  Unspecified              4
# 12          Female Genital Organs    Malignant              4
# 13    Respiratory & Intrathoracic    Malignant              4
# 14      Mesothelial & Soft Tissue    Malignant              2
# 15  Ill-defined & Secondary Sites    Malignant              2
# 16               Eye, Brain & CNS    Malignant              1
# 17       Secondary Neuroendocrine    Malignant              1
#
#     avg_claims_per_patient
# 0                 7.489627
# 1                 6.323077
# 2                 9.622222
# 3                17.060606
# 4                12.500000
# 5                20.230769
# 6                30.083333
# 7                19.000000
# 8                21.333333
# 9                 5.500000
# 10               34.400000
# 11                2.500000
# 12                4.750000
# 13               33.750000
# 14                3.500000
# 15               21.500000
# 16                2.000000
# 17                2.000000

# %% [markdown]
# ## Cost by Care Setting

# %%
cost_by_setting_df = con.sql("""
    SELECT 
        cs.care_setting_name,
        cs.care_setting_detail_name,
        SUM(f.paid_amount) as total_paid,
        SUM(f.claim_count) as total_claims,
        COUNT(DISTINCT f.person_id) as patients,
        ROUND(SUM(f.paid_amount) / NULLIF(COUNT(DISTINCT f.person_id), 0), 2) as avg_paid_per_patient,
        ROUND(SUM(f.paid_amount) / NULLIF(SUM(f.claim_count), 0), 2) as avg_paid_per_claim
    FROM main.fact_oncology_cost f
    JOIN main.dim_care_setting cs ON f.care_setting_key = cs.care_setting_key
    GROUP BY 1, 2
    ORDER BY care_setting_name, total_paid DESC
""").df()

cost_by_setting_df
# Out:
#    care_setting_name       care_setting_detail_name    total_paid  \
# 0          Ancillary                            lab  8.533683e+05
# 1          Ancillary                      ambulance  1.886267e+05
# 2          Ancillary      durable medical equipment  1.803833e+05
# 3          Inpatient                acute inpatient  2.536291e+06
# 4          Inpatient                       pharmacy  2.835269e+05
# 5          Inpatient                skilled nursing  1.134991e+05
# 6          Inpatient       inpatient rehabilitation  2.958890e+03
# 7          Inpatient          inpatient psychiatric  2.257700e+02
# 8       Office Based             office based visit  8.377722e+05
# 9       Office Based             office based other  7.250250e+05
# 10      Office Based         office based radiology  3.255994e+05
# 11      Office Based                       pharmacy  2.014653e+05
# 12      Office Based          office based pt/ot/st  5.063292e+04
# 13      Office Based               telehealth visit  8.080000e+00
# 14        Outpatient                       pharmacy  7.484368e+05
# 15        Outpatient  outpatient hospital or clinic  6.258924e+05
# 16        Outpatient      ambulatory surgery center  3.942924e+05
# 17        Outpatient           outpatient radiology  3.113596e+05
# 18        Outpatient             outpatient surgery  1.821431e+05
# 19        Outpatient           emergency department  1.251410e+05
# 20        Outpatient                    home health  5.152292e+04
# 21        Outpatient            outpatient pt/ot/st  2.335039e+04
# 22        Outpatient                    urgent care  6.894680e+03
# 23        Outpatient             outpatient hospice  1.985420e+03
# 24        Outpatient                    observation  1.633730e+03
# 25        Outpatient      outpatient rehabilitation  1.282100e+03
# 26        Outpatient                       dialysis  4.423900e+02
# 27        Outpatient         outpatient psychiatric  3.121700e+02
# 28           Unknown                          other  8.699110e+03
#
#     total_claims  patients  avg_paid_per_patient  avg_paid_per_claim
# 0        17549.0       474               1800.36               48.63
# 1          857.0       202                933.80              220.10
# 2         1332.0       286                630.71              135.42
# 3         4151.0       240              10567.88              611.01
# 4          166.0       124               2286.51             1707.99
# 5          313.0        41               2768.27              362.62
# 6           35.0         6                493.15               84.54
# 7            5.0         5                 45.15               45.15
# 8        11865.0       471               1778.71               70.61
# 9        11564.0       469               1545.90               62.70
# 10        2736.0       417                780.81              119.01
# 11         845.0       319                631.55              238.42
# 12         770.0       162                312.55               65.76
# 13           1.0         1                  8.08                8.08
# 14         758.0       313               2391.17              987.38
# 15        5952.0       463               1351.82              105.16
# 16        1424.0       222               1776.09              276.89
# 17        5201.0       443                702.84               59.87
# 18        1080.0       311                585.67              168.65
# 19        1746.0       313                399.81               71.67
# 20          54.0        45               1144.95              954.13
# 21          92.0        63                370.64              253.81
# 22         113.0        77                 89.54               61.01
# 23           1.0         1               1985.42             1985.42
# 24          86.0        76                 21.50               19.00
# 25           4.0         4                320.52              320.52
# 26           2.0         1                442.39              221.20
# 27           5.0         3                104.06               62.43
# 28         135.0        39                223.05               64.44

# %% [markdown]
# ## Spend Distribution by Cancer Type

# %%
spend_dist_df = con.sql("""
    SELECT 
        ct.cancer_type_name,
        ct.category,
        sb.spend_bucket_name,
        COUNT(DISTINCT f.person_id) as patient_count,
        SUM(f.paid_amount) as total_paid,
        SUM(f.claim_count) as total_claims
    FROM main.fact_oncology_cost f
    JOIN main.dim_cancer_type ct ON f.cancer_type_key = ct.cancer_type_key
    JOIN main.dim_spend_bucket sb ON f.spend_bucket_key = sb.spend_bucket_key
    GROUP BY 1, 2, 3
    ORDER BY total_paid DESC
    LIMIT 20
""").df()

spend_dist_df
# Out:
#                cancer_type_name   category         spend_bucket_name  \
# 0              Benign Neoplasms     Benign  Medium Cost ($25k-$100k)
# 1              Benign Neoplasms     Benign       Low Cost ($5k-$25k)
# 2            Uncertain Behavior  Uncertain       Low Cost ($5k-$25k)
# 3               Melanoma & Skin  Malignant  Medium Cost ($25k-$100k)
# 4              Benign Neoplasms     Benign        High Cost (>$100k)
# 5               Melanoma & Skin  Malignant       Low Cost ($5k-$25k)
# 6            Uncertain Behavior  Uncertain  Medium Cost ($25k-$100k)
# 7           Male Genital Organs  Malignant  Medium Cost ($25k-$100k)
# 8           Male Genital Organs  Malignant       Low Cost ($5k-$25k)
# 9                Other Neoplasm      Other  Medium Cost ($25k-$100k)
# 10                       Breast  Malignant  Medium Cost ($25k-$100k)
# 11                  Hematologic  Malignant  Medium Cost ($25k-$100k)
# 12               Other Neoplasm      Other       Low Cost ($5k-$25k)
# 13     Secondary Neuroendocrine  Malignant        High Cost (>$100k)
# 14             Benign Neoplasms     Benign       Minimal Cost (<$5k)
# 15                Urinary Tract  Malignant  Medium Cost ($25k-$100k)
# 16  Respiratory & Intrathoracic  Malignant  Medium Cost ($25k-$100k)
# 17                Urinary Tract  Malignant       Low Cost ($5k-$25k)
# 18   Thyroid & Endocrine Glands  Malignant       Low Cost ($5k-$25k)
# 19            In Situ Neoplasms    In Situ  Medium Cost ($25k-$100k)
#
#     patient_count    total_paid  total_claims
# 0              54  2.152609e+06       12184.0
# 1             148  1.862931e+06       21623.0
# 2              36  4.569612e+05        4593.0
# 3              11  4.419903e+05        2357.0
# 4               3  4.167581e+05         602.0
# 5              26  3.539794e+05        3135.0
# 6              10  3.330003e+05        1919.0
# 7               7  2.976955e+05        1586.0
# 8              21  2.886531e+05        2627.0
# 9               7  2.796309e+05        1362.0
# 10              7  2.451174e+05        1641.0
# 11              4  1.608659e+05         928.0
# 12             10  1.364070e+05        1611.0
# 13              1  1.162590e+05         210.0
# 14             36  1.096203e+05        2124.0
# 15              3  1.076194e+05         638.0
# 16              1  9.699433e+04         223.0
# 17              8  9.531298e+04         969.0
# 18              6  9.156894e+04         842.0
# 19              2  8.516703e+04         365.0

# %%
spend_by_cancer_df = con.sql("""
    SELECT 
        ct.cancer_type_name,
        ct.category,
        COUNT(DISTINCT f.person_id) as patient_count,
        SUM(f.paid_amount) as total_paid,
        SUM(f.claim_count) as total_claims,
        ROUND(SUM(f.paid_amount) / NULLIF(COUNT(DISTINCT f.person_id), 0), 2) as avg_paid_per_patient
    FROM main.fact_oncology_cost f
    JOIN main.dim_cancer_type ct ON f.cancer_type_key = ct.cancer_type_key
    GROUP BY 1, 2
    ORDER BY total_paid DESC
""").df()

spend_by_cancer_df
# Out:
#                  cancer_type_name     category  patient_count    total_paid  \
# 0                Benign Neoplasms       Benign            241  4.541918e+06
# 1              Uncertain Behavior    Uncertain             64  8.435100e+05
# 2                 Melanoma & Skin    Malignant             47  8.239682e+05
# 3             Male Genital Organs    Malignant             33  6.025821e+05
# 4                  Other Neoplasm        Other             20  4.231765e+05
# 5                          Breast    Malignant             14  3.090559e+05
# 6                     Hematologic    Malignant              9  2.314145e+05
# 7                   Urinary Tract    Malignant             11  2.029324e+05
# 8               In Situ Neoplasms      In Situ              5  1.350080e+05
# 9     Respiratory & Intrathoracic    Malignant              4  1.189264e+05
# 10       Secondary Neuroendocrine    Malignant              1  1.162590e+05
# 11     Thyroid & Endocrine Glands    Malignant              7  9.652538e+04
# 12               Digestive Organs    Malignant              6  8.766184e+04
# 13           Unspecified Behavior  Unspecified              4  8.522246e+04
# 14          Female Genital Organs    Malignant              4  7.522681e+04
# 15  Ill-defined & Secondary Sites    Malignant              2  5.002910e+04
# 16      Mesothelial & Soft Tissue    Malignant              2  2.380559e+04
# 17               Eye, Brain & CNS    Malignant              1  1.554903e+04
#
#     total_claims  avg_paid_per_patient
# 0        36533.0              18846.13
# 1         7688.0              13179.84
# 2         6001.0              17531.24
# 3         4575.0              18260.06
# 4         3087.0              21158.83
# 5         2559.0              22075.42
# 6         1873.0              25712.72
# 7         1607.0              18448.40
# 8          923.0              27001.61
# 9          545.0              29731.59
# 10         210.0             116259.03
# 11         938.0              13789.34
# 12         680.0              14610.31
# 13         579.0              21305.61
# 14         583.0              18806.70
# 15         195.0              25014.55
# 16         172.0              11902.79
# 17          94.0              15549.03

# %% [markdown]
# ## High Cost Patients Analysis

# %%
high_cost_df = con.sql("""
    SELECT 
        p.person_id,
        p.primary_cancer_type,
        ct.category,
        sb.spend_bucket_name,
        SUM(f.paid_amount) as total_paid,
        SUM(f.claim_count) as total_claims,
        p.all_cancer_codes
    FROM main.fact_oncology_cost f
    JOIN main.dim_patient p ON f.person_id = p.person_id
    JOIN main.dim_cancer_type ct ON f.cancer_type_key = ct.cancer_type_key
    JOIN main.dim_spend_bucket sb ON f.spend_bucket_key = sb.spend_bucket_key
    WHERE sb.spend_bucket_key = 1  -- High Cost (>$100k)
    GROUP BY 1, 2, 3, 4, 7
    ORDER BY total_paid DESC
    LIMIT 20
""").df()

high_cost_df
# Out:
#   person_id       primary_cancer_type   category   spend_bucket_name  \
# 0     10124          Benign Neoplasms     Benign  High Cost (>$100k)
# 1     12284          Benign Neoplasms     Benign  High Cost (>$100k)
# 2     13289          Benign Neoplasms     Benign  High Cost (>$100k)
# 3     11030  Secondary Neuroendocrine  Malignant  High Cost (>$100k)
#
#       total_paid  total_claims  \
# 0  166505.745377         105.0
# 1  125344.078149         153.0
# 2  124908.296561         344.0
# 3  116259.028908         210.0
#
#                                     all_cancer_codes
# 0                                 [C7A1, D126, D271]
# 1  [C44612, C61, D0339, D125, D171, D2239, D2261,...
# 2                                      [C3492, D235]
# 3                                       [C801, D481]

# %% [markdown]
# ## Care Setting Mix by Cancer Category

# %%
care_mix_df = con.sql("""
    SELECT 
        ct.category,
        SUM(CASE WHEN cs.care_setting_code = 'inpatient' THEN f.paid_amount ELSE 0 END) as inpatient,
        SUM(CASE WHEN cs.care_setting_code = 'outpatient' THEN f.paid_amount ELSE 0 END) as outpatient,
        SUM(CASE WHEN cs.care_setting_code = 'office-based' THEN f.paid_amount ELSE 0 END) as office_based,
        SUM(CASE WHEN cs.care_setting_code = 'ancillary' THEN f.paid_amount ELSE 0 END) as ancillary,
        SUM(CASE WHEN cs.care_setting_code = 'other' THEN f.paid_amount ELSE 0 END) as other,
        SUM(f.paid_amount) as total
    FROM main.fact_oncology_cost f
    JOIN main.dim_cancer_type ct ON f.cancer_type_key = ct.cancer_type_key
    JOIN main.dim_care_setting cs ON f.care_setting_key = cs.care_setting_key
    GROUP BY 1
    ORDER BY total DESC
""").df()

care_mix_df
# Out:
#       category     inpatient    outpatient  office_based      ancillary  \
# 0       Benign  1.492301e+06  1.286396e+06  1.120101e+06  638083.118722
# 1    Malignant  9.381525e+05  7.860580e+05  6.253130e+05  403710.819159
# 2    Uncertain  2.439349e+05  2.492698e+05  2.364091e+05  111587.380170
# 3        Other  2.071155e+05  8.922028e+04  7.549983e+04   51122.539872
# 4      In Situ  8.279080e+03  4.480692e+04  7.004100e+04   11881.040031
# 5  Unspecified  4.671851e+04  1.893812e+04  1.313889e+04    5993.430020
#
#          other         total
# 0  5036.389968  4.541918e+06
# 1   701.990000  2.753936e+06
# 2  2308.800016  8.435100e+05
# 3   218.420000  4.231765e+05
# 4     0.000000  1.350080e+05
# 5   433.510000  8.522246e+04

# %% [markdown]
# ## Summary Statistics

# %%
summary_df = con.sql("""
    SELECT
        COUNT(DISTINCT p.person_id) as total_patients,
        SUM(f.paid_amount) as total_paid,
        SUM(f.allowed_amount) as total_allowed,
        SUM(f.claim_count) as total_claims,
        ROUND(SUM(f.paid_amount) / NULLIF(COUNT(DISTINCT p.person_id), 0), 2) as avg_paid_per_patient,
        ROUND(SUM(f.paid_amount) / NULLIF(SUM(f.claim_count), 0), 2) as avg_paid_per_claim,
        ROUND(SUM(f.claim_count) * 1.0 / NULLIF(COUNT(DISTINCT p.person_id), 0), 2) as avg_claims_per_patient
    FROM main.fact_oncology_cost f
    JOIN main.dim_patient p ON f.person_id = p.person_id
""").df()

summary_df
# Out:
#    total_patients    total_paid  total_allowed  total_claims  \
# 0             475  8.782771e+06   5.499453e+06       68842.0
#
#    avg_paid_per_patient  avg_paid_per_claim  avg_claims_per_patient
# 0              18490.04              127.58                  144.93

# %% [markdown]
# ## Patient Detail

# %%
patient_detail_df = con.sql("""
    SELECT 
        p.person_id,
        p.cohort_name,
        p.primary_cancer_type,
        ct.category as cancer_category,
        p.cancer_claim_count,
        p.most_recent_diagnosis_date,
        sb.spend_bucket_name,
        cs.care_setting_name,
        cs.care_setting_detail_name,
        SUM(f.paid_amount) as total_paid,
        SUM(f.claim_count) as total_claims,
        p.all_cancer_codes,
        p.all_cancer_descriptions
    FROM main.dim_patient p
    LEFT JOIN main.fact_oncology_cost f ON p.person_id = f.person_id
    LEFT JOIN main.dim_cancer_type ct ON f.cancer_type_key = ct.cancer_type_key
    LEFT JOIN main.dim_care_setting cs ON f.care_setting_key = cs.care_setting_key
    LEFT JOIN main.dim_spend_bucket sb ON f.spend_bucket_key = sb.spend_bucket_key
    GROUP BY 1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 13
    ORDER BY total_paid DESC NULLS LAST
""").df()

patient_detail_df
# Out:
#      person_id      cohort_name          primary_cancer_type cancer_category  \
# 0        10124  Active Oncology             Benign Neoplasms          Benign
# 1        13289  Active Oncology             Benign Neoplasms          Benign
# 2        12284  Active Oncology             Benign Neoplasms          Benign
# 3        11030  Active Oncology     Secondary Neuroendocrine       Malignant
# 4        11524  Active Oncology  Respiratory & Intrathoracic       Malignant
# ...        ...              ...                          ...             ...
# 5586     11445  Active Oncology           Uncertain Behavior       Uncertain
# 5587      1070  Active Oncology              Melanoma & Skin       Malignant
# 5588     10145  Active Oncology                Urinary Tract       Malignant
# 5589     13208  Active Oncology              Melanoma & Skin       Malignant
# 5590     10133  Active Oncology             Benign Neoplasms          Benign
#
#       cancer_claim_count most_recent_diagnosis_date         spend_bucket_name  \
# 0                      3                 2017-08-04        High Cost (>$100k)
# 1                      2                 2018-03-14        High Cost (>$100k)
# 2                     11                 2017-12-04        High Cost (>$100k)
# 3                      2                 2017-11-23        High Cost (>$100k)
# 4                     61                 2018-07-16  Medium Cost ($25k-$100k)
# ...                  ...                        ...                       ...
# 5586                   3                 2018-11-26       Low Cost ($5k-$25k)
# 5587                   4                 2016-08-07       Low Cost ($5k-$25k)
# 5588                  13                 2018-03-13       Low Cost ($5k-$25k)
# 5589                  13                 2018-08-01  Medium Cost ($25k-$100k)
# 5590                  13                 2018-04-05  Medium Cost ($25k-$100k)
#
#      care_setting_name   care_setting_detail_name     total_paid  \
# 0            Inpatient            acute inpatient  159294.595344
# 1            Inpatient            acute inpatient  105751.616406
# 2           Outpatient                   pharmacy   99119.238144
# 3            Inpatient            skilled nursing   88039.948592
# 4            Inpatient            acute inpatient   68322.322472
# ...                ...                        ...            ...
# 5586         Ancillary  durable medical equipment       0.000000
# 5587        Outpatient                observation       0.000000
# 5588        Outpatient                   pharmacy       0.000000
# 5589         Inpatient                   pharmacy       0.000000
# 5590        Outpatient        outpatient pt/ot/st     -69.990000
#
#       total_claims                                   all_cancer_codes  \
# 0             19.0                                 [C7A1, D126, D271]
# 1             78.0                                      [C3492, D235]
# 2              5.0  [C44612, C61, D0339, D125, D171, D2239, D2261,...
# 3             41.0                                       [C801, D481]
# 4             54.0  [C039, C153, C159, C3411, C3412, C3431, C3432,...
# ...            ...                                                ...
# 5586           1.0                               [C44311, D485, D494]
# 5587           1.0                               [C44319, D225, D485]
# 5588           2.0  [C3490, C44519, C642, C649, C7951, C801, C8333...
# 5589           1.0  [C069, C44310, C44519, C4490, C50912, C649, D0...
# 5590           2.0  [C4359, C44319, C44329, D0422, D123, D124, D12...
#
#                                 all_cancer_descriptions
# 0     [Malignant poorly differentiated neuroendocrin...
# 1     [Malignant neoplasm of unspecified part of lef...
# 2     [Basal cell carcinoma of skin of right upper l...
# 3     [Malignant (primary) neoplasm, unspecified, Ne...
# 4     [Malignant neoplasm of gum, unspecified, Malig...
# ...                                                 ...
# 5586  [Basal cell carcinoma of skin of nose, Neoplas...
# 5587  [Basal cell carcinoma of skin of other parts o...
# 5588  [Malignant neoplasm of unspecified part of uns...
# 5589  [Malignant neoplasm of mouth, unspecified, Bas...
# 5590  [Malignant melanoma of other part of trunk, Ba...
#
# [5591 rows x 13 columns]

# %%
con.close()
