# %%
import duckdb
conn = duckdb.connect('../../local.duckdb')

# %%
conn.sql("summarize stg_providers").df()
# Out:
#             column_name column_type                         min  \
# 0       practitioner_id     VARCHAR                  1003002809
# 1                   npi     VARCHAR                  1003002809
# 2   provider_first_name     VARCHAR                           A
# 3    provider_last_name     VARCHAR                       Aaboe
# 4  practice_affiliation     VARCHAR                        None
# 5             specialty     VARCHAR               Acupuncturist
# 6         sub_specialty     VARCHAR                        None
# 7           data_source     VARCHAR                        None
# 8         tuva_last_run   TIMESTAMP  2025-12-28 18:29:03.120763
#
#                           max  approx_unique                         avg  \
# 0                  1992999122          50741                        None
# 1                  1992999122          50741                        None
# 2                         Zvi           8686                        None
# ...

# %%
conn.sql("summarize stg_immunizations").df()
# Out:
#                column_name column_type  \
# 0          immunization_id     VARCHAR
# 1                person_id     VARCHAR
# 2               patient_id     VARCHAR
# 3             encounter_id     VARCHAR
# 4         source_code_type     VARCHAR
# 5              source_code     VARCHAR
# 6       source_description     VARCHAR
# 7     normalized_code_type     VARCHAR
# 8          normalized_code     VARCHAR
# 9   normalized_description     VARCHAR
# 10          mapping_method     VARCHAR
# 11                  status     VARCHAR
# 12           status_reason     VARCHAR
# 13         occurrence_date        DATE
# 14             source_dose     VARCHAR
# 15         normalized_dose     VARCHAR
# 16              lot_number     VARCHAR
# 17               body_site     VARCHAR
# 18                   route     VARCHAR
# 19             location_id     VARCHAR
# 20         practitioner_id     VARCHAR
# 21             data_source     VARCHAR
# 22           tuva_last_run   TIMESTAMP
#
# ...
